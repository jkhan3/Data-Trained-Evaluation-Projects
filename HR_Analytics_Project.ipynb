# %% [markdown]
# # Problem Statement:

# %% [markdown]
# Every year a lot of companies hire a number of employees. The companies invest time and money in training those employees, not just this but there are training programs within the companies for their existing employees as well. The aim of these programs is to increase the effectiveness of their employees. But where HR Analytics fit in this? and is it just about improving the performance of employees?
#
# **HR Analytics**
#
# Human resource analytics (HR analytics) is an area in the field of analytics that refers to applying analytic processes to the human resource department of an organization in the hope of improving employee performance and therefore getting a better return on investment. HR analytics does not just deal with gathering data on employee efficiency. Instead, it aims to provide insight into each process by gathering data and then using it to make relevant decisions about how to improve these processes.
#
# **Attrition in HR**
#
# Attrition in human resources refers to the gradual loss of employees overtime. In general, relatively high attrition is problematic for companies. HR professionals often assume a leadership role in designing company compensation programs, work culture, and motivation systems that help the organization retain top employees.
#
# How does Attrition affect companies? and how does HR Analytics help in analyzing attrition? We will discuss the first question here and for the second question, we will write the code and try to understand the process step by step.
#
# **Attrition affecting Companies**
#
# A major problem in high employee attrition is its cost to an organization. Job postings, hiring processes, paperwork, and new hire training are some of the common expenses of losing employees and replacing them. Additionally, regular employee turnover prohibits your organization from increasing its collective knowledge base and experience over time. This is especially concerning if your business is customer-facing, as customers often prefer to interact with familiar people. Errors and issues are more likely if you constantly have new workers.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px 
import warnings
warnings.filterwarnings('ignore')

# %%
hr_employee = pd.read_csv("HR_Employee.csv")
hr_employee.head().T
# Out:
#                                         0                       1  \
# Age                                    41                      49
# Attrition                             Yes                      No
# BusinessTravel              Travel_Rarely       Travel_Frequently
# DailyRate                            1102                     279
# Department                          Sales  Research & Development
# DistanceFromHome                        1                       8
# Education                               2                       1
# EducationField              Life Sciences           Life Sciences
# EmployeeCount                           1                       1
# EmployeeNumber                          1                       2
# EnvironmentSatisfaction                 2                       3
# Gender                             Female                    Male
# HourlyRate                             94                      61
# ...

# %% [markdown]
# # EDA

# %%
hr_employee.shape
# Out:
# (1470, 35)

# %% [markdown]
# There are 1470 rows and 35 columns

# %%
hr_employee.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %%
hr_employee.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(hr_employee.isnull(),yticklabels=True,cbar=True,cmap='viridis')
plt.show()

# %% [markdown]
# There are no missing values.

# %%
hr_employee.nunique().sort_values(ascending=True)
# Out:
# Over18                         1
# StandardHours                  1
# EmployeeCount                  1
# Gender                         2
# Attrition                      2
# PerformanceRating              2
# OverTime                       2
# MaritalStatus                  3
# Department                     3
# BusinessTravel                 3
# StockOptionLevel               4
# EnvironmentSatisfaction        4
# JobInvolvement                 4
# JobSatisfaction                4
# RelationshipSatisfaction       4
# WorkLifeBalance                4
# Education                      5
# JobLevel                       5
# EducationField                 6
# TrainingTimesLastYear          7
# JobRole                        9
# NumCompaniesWorked            10
# PercentSalaryHike             15
# YearsSinceLastPromotion       16
# YearsWithCurrManager          18
# YearsInCurrentRole            19
# DistanceFromHome              29
# YearsAtCompany                37
# ...

# %% [markdown]
# Lets remove the columns (EmployeeNumber,Over18, StandardHours and EmployeeCount) as those are not sigficanly helping in model,
# EmployeeNumber is a unique key having unique value for each row and Over18, StandardHours and EmployeeCount has unique values they don't bring any significance for model

# %%
hr_employee.drop(['Over18','StandardHours','EmployeeCount','EmployeeNumber'],axis=1,inplace=True)

# %%
hr_employee.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# ...

# %% [markdown]
# Dataset have 8 columns with object type data (Attrition, BusinessTravel, Department, EducationField,  Gender, JobRole, MaritalStatus, OverTime), which we will have to encode

# %%
#Performing scaling to Attrition
hr_employee.Attrition.replace(['Yes','No'],[1,0],inplace=True)

# %%
# Object datatypes
obj_feature = hr_employee.select_dtypes(include=['object'])
# Numerical datatypes
num_feature = hr_employee.select_dtypes(exclude=['object'])

# %%
# Relation of target variable with few Categorical features

obj_fea = ['BusinessTravel','Department','EducationField','JobRole','MaritalStatus', 'OverTime']

plt.figure(figsize=(25,30))
for i,feat in enumerate(hr_employee[obj_fea]):
    plt.subplot(3,2,i+1)
    sns.barplot(x=hr_employee[feat],y=hr_employee['Attrition'])
    plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Observations : -
#
# 1. Who travel frequently for business purpose tends to leave company early than who travel rarely and Who don't need to travel will stay in company than others
#
# 2. Reasearch and Development team employees will stay longer in company than other departments
#
# 3. Whose education background is from Human resources,Techical degrees, Marketing tends to leave company than other ones from other Educational background
#
# 4. Sales representatives will leave company much earlier than others, Research Directors rarely leaves the company
#
# 5. Singles tends to leave company than Married ones and divorced

# %%
#fetching the column with dtype int and unique value > 30 for continues data plotting

cont_col = []
for column in hr_employee.columns:
    if hr_employee[column].dtypes != object and hr_employee[column].nunique() > 30:
        print(f"{column} : Minimum: {hr_employee[column].min()}, Maximum: {hr_employee[column].max()}")
        cont_col.append(column)
        print("::::::::::::::::::::::::::::::::::::::::::")
# Out:
# Age : Minimum: 18, Maximum: 60
# ::::::::::::::::::::::::::::::::::::::::::
# DailyRate : Minimum: 102, Maximum: 1499
# ::::::::::::::::::::::::::::::::::::::::::
# HourlyRate : Minimum: 30, Maximum: 100
# ::::::::::::::::::::::::::::::::::::::::::
# MonthlyIncome : Minimum: 1009, Maximum: 19999
# ::::::::::::::::::::::::::::::::::::::::::
# MonthlyRate : Minimum: 2094, Maximum: 26999
# ::::::::::::::::::::::::::::::::::::::::::
# TotalWorkingYears : Minimum: 0, Maximum: 40
# ::::::::::::::::::::::::::::::::::::::::::
# YearsAtCompany : Minimum: 0, Maximum: 40
# ::::::::::::::::::::::::::::::::::::::::::

# %%
plt.figure(figsize=(20, 10))
for i, column in enumerate(cont_col, 1):

    plt.subplot(2, 4, i)
    
    sns.kdeplot(data = hr_employee[hr_employee['Attrition'] == 0], x = column, shade = True,  alpha = 1, color = '#512b58',Label='Attrition = NO' )
    sns.kdeplot(data = hr_employee[hr_employee['Attrition'] == 1], x = column, shade = True,  alpha = 0.8, color = '#fe346e',Label='Attrition = YES')
    plt.legend()

# %% [markdown]
# * Teenagers highly tends to leave company than Mid aged
# * Employees who have high experience will tend to leave company, Later who joined recently tends to leave
# * Seniors in company tends to leave sooner than others

# %%
# DistanceFromHome

plt.figure(figsize=(10,8))
sns.barplot(x=hr_employee['DistanceFromHome'],y=hr_employee['Attrition'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Who travels from long distance to workplace tends leave company than others

# %%
# Education

plt.figure(figsize=(10,8))
sns.barplot(x=hr_employee['Education'],y=hr_employee['Attrition'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Who is less educated tends to leave company sooner than others

# %%
# EnvironmentSatisfaction

plt.figure(figsize=(10,8))
sns.barplot(x=hr_employee['EnvironmentSatisfaction'],y=hr_employee['Attrition'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Who leastly likes the environment in company tends to leave company sooner than others

# %%
# JobInvolvement

plt.figure(figsize=(10,8))
sns.barplot(x=hr_employee['JobInvolvement'],y=hr_employee['Attrition'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Who leastly involves in Job in company tends to leave company sooner than others

# %%
#Plotting other feature for numeric features
other_fea = ['NumCompaniesWorked','PercentSalaryHike','PerformanceRating','RelationshipSatisfaction','StockOptionLevel']

plt.figure(figsize=(20,20))
for i,feat in enumerate(other_fea):
    plt.subplot(3,2,i+1)
    sns.barplot( x=hr_employee[feat],y=hr_employee['Attrition'])
    plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# * Who worked for more number of compannies tends to switch again!
#
# * Who works overtime tends to leave early
#
# * Surprisingly Who got more percentage of hike tending to leave company!
#
# * Performance Rating 3 & 4 Almost equal probability to leave or stay in company (We might need to remove this feature, because it doesn't have much say in Modeling
#
# * Who have less Relationship Satisfaction tends to leave earlier than other
#
# * Who have no company stocks tends to leave than who have more options, Who have more stock options tends to leave than who have comparitively less options.

# %%
#Plotting other feature for numeric columns
other_fea = ['TotalWorkingYears','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']

plt.figure(figsize=(20,20))
for i,feat in enumerate(other_fea):
    plt.subplot(3,2,i+1)
    sns.barplot(x=hr_employee[feat],y=hr_employee['Attrition'])
    plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# * Employees who have 40 years experience will tend to leave company, Later who joined recently (whose experience is below 2) tends to leave
#
# * Who have least worklife balance tends to resign faster than other
#
# * Seniors in company tends to leave sooner than others
#
# * Who stays in current role for longer time and who just got new role tends to leave company sooner than others
#
# * Who don't get promotion for long time tends to leave comapany
#
# * Who stays with Manager for longer time and shorter time tends to leave company than others

# %%
hr_employee.head().T
# Out:
#                                         0                       1  \
# Age                                    41                      49
# Attrition                               1                       0
# BusinessTravel              Travel_Rarely       Travel_Frequently
# DailyRate                            1102                     279
# Department                          Sales  Research & Development
# DistanceFromHome                        1                       8
# Education                               2                       1
# EducationField              Life Sciences           Life Sciences
# EnvironmentSatisfaction                 2                       3
# Gender                             Female                    Male
# HourlyRate                             94                      61
# JobInvolvement                          3                       2
# JobLevel                                2                       2
# ...

# %%
hr_employee.corr()
# Out:
#                                Age  Attrition  DailyRate  DistanceFromHome  \
# Age                       1.000000  -0.159205   0.010661         -0.001686
# Attrition                -0.159205   1.000000  -0.056652          0.077924
# DailyRate                 0.010661  -0.056652   1.000000         -0.004985
# DistanceFromHome         -0.001686   0.077924  -0.004985          1.000000
# Education                 0.208034  -0.031373  -0.016806          0.021042
# EnvironmentSatisfaction   0.010146  -0.103369   0.018355         -0.016075
# HourlyRate                0.024287  -0.006846   0.023381          0.031131
# JobInvolvement            0.029820  -0.130016   0.046135          0.008783
# JobLevel                  0.509604  -0.169105   0.002966          0.005303
# JobSatisfaction          -0.004892  -0.103481   0.030571         -0.003669
# MonthlyIncome             0.497855  -0.159840   0.007707         -0.017014
# ...

# %%
plt.figure(figsize=(20,20))

sns.heatmap(hr_employee.corr(),annot=True,cmap='Greys')

plt.show()

# %% [markdown]
# * Joblevel is highly corelated with MonthlyIncome (95%)
# * JobLevel is correlated with TotalExperience (78%)
# * Percentage of SalaryHike is related to PerformanceRating (77%)
# * MonthlyIncome is correlated with TotalExperience (77%)
# * YearsAtCompany is correlated with YearswithCurrentManager (77%)
# * YearsAtCompany is correlated with YearCurrentRole (76%)
# * Attrition rate is comparatevely highly correlated with OverTime (25%)

# %% [markdown]
# # Pre-processing

# %%
hr_employee.head().T
# Out:
#                                         0                       1  \
# Age                                    41                      49
# Attrition                               1                       0
# BusinessTravel              Travel_Rarely       Travel_Frequently
# DailyRate                            1102                     279
# Department                          Sales  Research & Development
# DistanceFromHome                        1                       8
# Education                               2                       1
# EducationField              Life Sciences           Life Sciences
# EnvironmentSatisfaction                 2                       3
# Gender                             Female                    Male
# HourlyRate                             94                      61
# JobInvolvement                          3                       2
# JobLevel                                2                       2
# ...

# %%
hr_employee.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# DailyRate                  -0.003519
# DistanceFromHome            0.958118
# Education                  -0.289681
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobSatisfaction            -0.329672
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     1.984290
# YearsWithCurrManager        0.833451
# dtype: float64

# %% [markdown]
# There is not much skewness present in the data, except few coloums (JobLevel,MonthlyIncome,NumCompaniesWorked,PerformanceRating, TotalWorkingYears,YearsAtCompany,YearsSinceLastPromotion), which can be avaoided

# %%
# To remove skewness from the above column we use log transformation

hr_employee['JobLevel']=np.log(hr_employee['JobLevel'])
hr_employee['MonthlyIncome']=np.log(hr_employee['MonthlyIncome'])
hr_employee['PerformanceRating']=np.log(hr_employee['PerformanceRating'])

# %%
hr_employee.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# DailyRate                  -0.003519
# DistanceFromHome            0.958118
# Education                  -0.289681
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    0.219763
# JobSatisfaction            -0.329672
# MonthlyIncome               0.286192
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     1.984290
# YearsWithCurrManager        0.833451
# dtype: float64

# %% [markdown]
# ### Use LabelEncoder() to encode the Text-based features into Integers.

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()

hr_employee["BusinessTravel"] = label.fit_transform(hr_employee['BusinessTravel'])
hr_employee["Department"] = label.fit_transform(hr_employee['Department'])
hr_employee["EducationField"] = label.fit_transform(hr_employee['EducationField'])
hr_employee["Gender"] = label.fit_transform(hr_employee['Gender'])
hr_employee["JobRole"] = label.fit_transform(hr_employee['JobRole'])
hr_employee["MaritalStatus"] = label.fit_transform(hr_employee['MaritalStatus'])
hr_employee["OverTime"] = label.fit_transform(hr_employee['OverTime'])

# %%
hr_employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   int32
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int32
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   int32
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   int32
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   float64
#  13  JobRole                   1470 non-null   int32
# ...

# %% [markdown]
# #### Separating the dependent and independent variables with angle of AveragePrice.

# %%
x=hr_employee.copy()
x.drop('Attrition',axis=1,inplace=True)

y=hr_employee['Attrition']

# %% [markdown]
# #### Scaling the data

# %%
#Scaling the data using standard scaler
from sklearn.preprocessing import StandardScaler 
sc = StandardScaler()

xd=sc.fit_transform(x)
x=pd.DataFrame(xd,columns=x.columns)

# %% [markdown]
# # Building Machine Learning Models

# %%
from sklearn.linear_model import LogisticRegression,LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, accuracy_score, confusion_matrix, roc_auc_score, ConfusionMatrixDisplay, precision_score, recall_score, f1_score, classification_report, roc_curve, plot_roc_curve, auc, precision_recall_curve, plot_precision_recall_curve, average_precision_score
from sklearn.model_selection import cross_val_score, train_test_split

# %%
#Choosing the best random state using Logistic regression

def randomstate(a,b):
    maxx=1000
    for state in range(1,201):
        xtrain,xtest,ytrain,ytest=train_test_split(a,b,test_size=0.25,random_state=state)
        model=LinearRegression()
        model.fit(xtrain,ytrain)
        p=model.predict(xtest)
        mse=mean_squared_error(p,ytest)
        if maxx>mse:
            maxx=mse
            j=state
    return j

# %%
#Creating list of models and another list mapped to their names
models=[LogisticRegression(),KNeighborsClassifier(),SVC(),GaussianNB(),BernoulliNB(),DecisionTreeClassifier(),RandomForestClassifier(),XGBClassifier()]

names=['LogisticRegression','KNeighborsClassifier','SVC','GaussianNB','BernoulliNB','DecisionTreeClassifier','RandomForestClassifier','XGBClassifier']

# %%
#Creating methord for the models and appending them to data frame

def createmodels(model_list,independent,dependent,n):
    xtrain,xtest,ytrain,ytest=train_test_split(independent,dependent,test_size=0.25,random_state=randomstate(independent,dependent))
    name=[]
    meanabs=[]
    meansqd=[]
    rootmeansqd=[]
    r2=[]
    mcv=[]
    
    #Creating models
    for i,model in enumerate(model_list):
        model.fit(xtrain,ytrain)
        p=model.predict(xtest)
        score=cross_val_score(model,independent,dependent,cv=10)
        
        #Calculating scores of the model and appending them to a list
        name.append(n[i])
        meanabs.append(np.round(mean_absolute_error(p,ytest),4))
        meansqd.append(np.round(mean_squared_error(p,ytest),4))
        rootmeansqd.append(np.round(np.sqrt(mean_squared_error(p,ytest)),4))
        r2.append(np.round(r2_score(p,ytest),2))
        mcv.append(np.round(np.mean(score),4))
    
    #Creating Dataframe
    data=pd.DataFrame()
    data['Model']=name
    data['Mean Absolute Error']=meanabs
    data['Mean Squared Error']=meansqd
    data['Root Mean Squared Error']=rootmeansqd
    data['R2 Score']=r2
    data['Mean of Cross validaton Score']=mcv
    data.set_index('Model',inplace = True)
    return data

# %%
createmodels(models,x,y,names)
# Out:
# [19:21:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:21:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:21:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %% [markdown]
# #### Removing multicollinearity ussing L1 Regularisation

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={'alpha':[1e-15,1e-10,1e-8,1e-5,1e-3,0.1,1,5,10,15,20,30,35,45,50,55,65,100,110,150,1000]}
m1=GridSearchCV(Lasso(),param_grid,scoring='neg_mean_squared_error',cv=10)
m1.fit(x,y)
print(m1.best_params_)
# Out:
# {'alpha': 0.001}

# %%
m1=Lasso(alpha=0.001)
m1.fit(x,y)
# Out:
# Lasso(alpha=0.001)

# %%
importance = np.abs(m1.coef_)

# %%
dfcolumns = pd.DataFrame(x.columns)
dfimp=pd.DataFrame(importance)
featureScores = pd.concat([dfcolumns,dfimp],axis=1)
featureScores.columns = ['Features','Coefficients']  #naming the dataframe columns
featureScores
# Out:
#                     Features  Coefficients
# 0                        Age      0.034901
# 1             BusinessTravel      0.000000
# 2                  DailyRate      0.012369
# 3                 Department      0.034781
# 4           DistanceFromHome      0.027208
# 5                  Education      0.000000
# 6             EducationField      0.005736
# 7    EnvironmentSatisfaction      0.044494
# 8                     Gender      0.015884
# 9                 HourlyRate      0.004314
# 10            JobInvolvement      0.042520
# 11                  JobLevel      0.011084
# 12                   JobRole      0.008905
# 13           JobSatisfaction      0.040960
# 14             MaritalStatus      0.037243
# 15             MonthlyIncome      0.054451
# 16               MonthlyRate      0.003097
# 17        NumCompaniesWorked      0.040033
# 18                  OverTime      0.094313
# 19         PercentSalaryHike      0.009925
# 20         PerformanceRating      0.004205
# ...

# %%
featureScores.sort_values(by=['Coefficients'],ascending=False)
# Out:
#                     Features  Coefficients
# 18                  OverTime      0.094313
# 15             MonthlyIncome      0.054451
# 7    EnvironmentSatisfaction      0.044494
# 10            JobInvolvement      0.042520
# 13           JobSatisfaction      0.040960
# 17        NumCompaniesWorked      0.040033
# 14             MaritalStatus      0.037243
# 28   YearsSinceLastPromotion      0.034916
# 0                        Age      0.034901
# 3                 Department      0.034781
# 29      YearsWithCurrManager      0.032730
# 27        YearsInCurrentRole      0.030349
# 4           DistanceFromHome      0.027208
# 26            YearsAtCompany      0.026764
# 21  RelationshipSatisfaction      0.022528
# 22          StockOptionLevel      0.021162
# 25           WorkLifeBalance      0.017579
# 8                     Gender      0.015884
# 24     TrainingTimesLastYear      0.014970
# 2                  DailyRate      0.012369
# 11                  JobLevel      0.011084
# ...

# %%
#We remove 1 feature
lassoxt=x.copy()
lassoxt.drop(['Education'],axis=1,inplace=True)
createmodels(models,lassoxt,y,names)
# Out:
# [19:36:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:36:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:36:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
#We remove these 2 features
lassoxt=x.copy()
lassoxt.drop(['BusinessTravel','TotalWorkingYears'],axis=1,inplace=True)
createmodels(models,lassoxt,y,names)
# Out:
# [19:37:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:37:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:37:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %% [markdown]
# As removing features also leads to some data loss, so the model's performance will decreased, therefore we will not remove any features.

# %% [markdown]
# ### Hyperparameter Tuning for Logistic and RandomForest as those are giving best result

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.25,random_state=randomstate(x,y))

# %%
from sklearn.model_selection import GridSearchCV
grid_models = [(LogisticRegression(),[{'C':[0.25,0.5,0.75,1],'random_state':[0]}]),(RandomForestClassifier(),[{'n_estimators':[100,150,200],'criterion':['gini','entropy'],'random_state':[0]}])]

# %%
for i,j in grid_models:
    grid = GridSearchCV(estimator=i,param_grid = j, scoring = 'accuracy',cv = 10)
    grid.fit(xtrain, ytrain)
    best_accuracy = grid.best_score_
    best_param = grid.best_params_
    best_estimator = grid.best_estimator_
    print('{}:\nBest Accuracy : {:.2f}%'.format(i,best_accuracy*100))
    print('Best Parameters : ',best_param)
    print('Best Estimator :',best_estimator)
    print('')
    print('----------------')
    print('')
# Out:
# LogisticRegression():
# Best Accuracy : 85.20%
# Best Parameters :  {'C': 0.25, 'random_state': 0}
# Best Estimator : LogisticRegression(C=0.25, random_state=0)
#
# ----------------
#
# RandomForestClassifier():
# Best Accuracy : 84.21%
# Best Parameters :  {'criterion': 'entropy', 'n_estimators': 100, 'random_state': 0}
# Best Estimator : RandomForestClassifier(criterion='entropy', random_state=0)
#
# ----------------

# %% [markdown]
# # Finalizing the Model

# %%
model=RandomForestClassifier(criterion='entropy', random_state=0)
model.fit(xtrain,ytrain)
p=model.predict(xtest)
score=cross_val_score(model,x,y,cv=10)

# %%
print('Mean Absolute Error is',np.round(mean_absolute_error(p,ytest),4))
print('Mean Squared Error is',np.round(mean_squared_error(p,ytest),4))
print('Root Mean Squared Error is',np.round(np.sqrt(mean_squared_error(p,ytest)),4))
print('R2 Score is',np.round(r2_score(p,ytest),4)*100)
print('Mean of cross validaton Score is',np.round(np.mean(score)*100,4))
# Out:
# Mean Absolute Error is 0.0897
# Mean Squared Error is 0.0897
# Root Mean Squared Error is 0.2995
# R2 Score is -163.14
# Mean of cross validaton Score is 85.6463

# %% [markdown]
# # Saving Model

# %%
import joblib
joblib.dump(model,'hr_analytics.obj')
# Out:
# ['hr_analytics.obj']
